# %%
# %pip install tweepy

# %%
import requests 
import json
import os
from dotenv import load_dotenv
import pandas as pd
from pandas import json_normalize
import tweepy
import time

# %%
prueba = requests.get('https://www.genenetwork.nl/api/v1/prioritization/HP:0001874,HP:0001419,HP:0002718,HP:0004313,HP:0000951')

# %%
pruebs= prueba.json()
pruebs
# Out:
# {'termsNotFound': [],
#  'termsFound': [{'id': 'HP:0001874', 'name': 'Abnormality of neutrophils'},
#   {'id': 'HP:0001419', 'name': 'X-linked recessive inheritance'},
#   {'id': 'HP:0002718', 'name': 'Recurrent bacterial infections'},
#   {'id': 'HP:0004313', 'name': 'Decreased antibody level in blood'},
#   {'id': 'HP:0000951', 'name': 'Abnormality of the skin'}],
#  'terms': [{'href': 'http://www.genenetwork.nl/api/v1/pathway/HP:0001874',
#    'term': {'database': 'HPO',
#     'id': 'HP:0001874',
#     'name': 'Abnormality of neutrophils',
#     'url': 'https://hpo.jax.org/app/browse/term/HP:0001874',
#     'numAnnotatedGenes': 168,
#     'auc': 0.7558583353009927,
#     'index_': 644}},
#   {'href': 'http://www.genenetwork.nl/api/v1/pathway/HP:0001419',
#    'term': {'database': 'HPO',
#     'id': 'HP:0001419',
#     'name': 'X-linked recessive inheritance',
#     'url': 'https://hpo.jax.org/app/browse/term/HP:0001419',
#     'numAnnotatedGenes': 144,
# ...

# %%
type(pruebs)
# Out:
# dict

# %%
child1=pd.read_csv('../data/Child1_genome.csv')

# %%
child1['# rsid'].index('rs63125872')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-ef86824a6b90> in <module>
# ----> 1 child1['# rsid'].index('rs63125872')
#
# TypeError: 'RangeIndex' object is not callable
